# %%
# %matplotlib notebook
import bt

# %%
# fetch some data
data = bt.get('ndx,agg', start='2010-01-01')
print(data.head())
# Out:
#                     ndx        agg
# Date
# 2010-01-04  1886.699951  80.051933
# 2010-01-05  1888.430054  80.416130
# 2010-01-06  1878.420044  80.369637
# 2010-01-07  1876.719971  80.276611
# 2010-01-08  1892.589966  80.323082

# %%
# Create the strategy
# create the strategy
s = bt.Strategy('s1', [bt.algos.RunMonthly(),
                       bt.algos.SelectAll(),
                       bt.algos.WeighEqually(),
                       bt.algos.Rebalance()])

# %%
# create a backtest and run it
test = bt.Backtest(s, data)
res = bt.run(test)
# Out:
# s1
# 0% [############################# ] 100% | ETA: 00:00:00
# C:\Users\User\Anaconda3\lib\site-packages\ffn\core.py:2056: RuntimeWarning: divide by zero encountered in true_divide
#   res = np.divide(er.mean(), std)

# %%
# first let's see an equity curve
res.plot()
# Out:
# <img src="data:image/png;base64,..." width="1500">

# %%
# ok and what about some stats?
res.display()
# Out:
# Stat                 s1
# -------------------  ----------
# Start                2010-01-03
# End                  2019-06-07
# Risk-free rate       0.00%
#
# Total Return         140.56%
# Daily Sharpe         1.16
# Daily Sortino        1.87
# CAGR                 9.76%
# Max Drawdown         -11.46%
# Calmar Ratio         0.85
#
# MTD                  2.31%
# 3m                   4.93%
# 6m                   7.94%
# YTD                  11.34%
# 1Y                   6.26%
# 3Y (ann.)            10.31%
# 5Y (ann.)            8.80%
# 10Y (ann.)           9.76%
# Since Incep. (ann.)  9.76%
#
# Daily Sharpe         1.16
# Daily Sortino        1.87
# Daily Mean (ann.)    9.88%
# Daily Vol (ann.)     8.51%
# Daily Skew           -0.34
# Daily Kurt           3.45
# Best Day             3.01%
# Worst Day            -3.37%
#
# Monthly Sharpe       1.34
# Monthly Sortino      2.98
# Monthly Mean (ann.)  9.98%
# Monthly Vol (ann.)   7.42%
# Monthly Skew         -0.06
# Monthly Kurt         -0.20
# Best Month           6.37%
# Worst Month          -4.64%
#
# Yearly Sharpe        1.61
# Yearly Sortino       inf
# Yearly Mean          8.94%
# Yearly Vol           5.54%
# Yearly Skew          -0.13
# Yearly Kurt          -1.04
# Best Year            16.81%
# Worst Year           0.08%
#
# Avg. Drawdown        -1.08%
# Avg. Drawdown Days   16.96
# Avg. Up Month        2.12%
# Avg. Down Month      -1.43%
# Win Year %           100.00%
# Win 12m %            96.12%

# %%
# ok and how does the return distribution look like?
res.plot_histogram()
# Out:
# <img src="data:image/png;base64,..." width="1500">
# C:\Users\User\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6521: MatplotlibDeprecationWarning:
# The 'normed' kwarg was deprecated in Matplotlib 2.1 and will be removed in 3.1. Use 'density' instead.
#   alternative="'density'", removal="3.1")

# %%
# and just to make sure everything went along as planned, let's plot the security weights over time
res.plot_security_weights()
# Out:
# <img src="data:image/png;base64,..." width="1500">

# %%
# http://pmorissette.github.io/bt/examples.html
